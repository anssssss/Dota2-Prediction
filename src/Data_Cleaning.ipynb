# %% [markdown]
# # Extract collected data

# %% [markdown]
# ## Teams and their rankings

# %%
from pandas import read_csv

teams = read_csv('../data/ranks/2020-06-24.csv')

# %% [markdown]
# History window size

# %%
size = 5

# %%
from os import listdir

collected_teams = listdir('../data/teams')

for index, row in teams.iterrows():
    name = row['name'].replace('.', '').replace('"', '') + '.csv'
    if name in collected_teams:
        team = read_csv('../data/teams/' + name)
# Out:
#   False       Heroic     982
# 1   False       Heroic     982
# 2    True         NOVA    1133
# 3    True         NOVA    1133
# 4   False         NOVA    1133
# 5   False  Team Unique    1144
# 6   False  Team Unique    1144
# 7    True  Team Unique    1144
# 8   False        TEMPO    1066
# 9   False        TEMPO    1066
# 10   True        TEMPO    1066
# 11   True        CR4ZY    1163
# 12  False        CR4ZY    1163
# 13   True        CR4ZY    1163
# 14   True     ViKin.gg    1286
# 15  False     ViKin.gg    1286
# 16   True     ViKin.gg    1286
# 17   True           B8    1004
# 18  False           B8    1004
# 19   True           B8    1004
# 20  False         KHAN    1087
# 21  False         KHAN    1087
# 22  False   CYBERIUM.S    1011
# 23  False   CYBERIUM.S    1011
# 24  False  FAMILY TEAM    1119
# 25  False  FAMILY TEAM    1119
#      lost       opponent  o_rank
# 0    True         Fnatic    1391
# 1    True         Fnatic    1391
# 2    True         Fnatic    1391
# ...

# %%
teams
# Out:
#                      name            link  rank
# 0                 PSG.LGD       /teams/15  1567
# 1             Team Secret  /teams/1838315  1561
# 2         INVICTUS GAMING        /teams/5  1496
# 3                   Nigma  /teams/7554697  1429
# 4                   CDEC   /teams/1520578  1392
# 5                  Fnatic   /teams/350190  1391
# 6                   EHOME        /teams/4  1376
# 7     Royal Never Give Up  /teams/6209804  1373
# 8             Vici Gaming   /teams/726228  1368
# 9                Scenario      /teams/166  1367
# 10              FlyToMoon  /teams/6953913  1355
# 11            Team Liquid     /teams/2163  1345
# 12             VP.Prodigy  /teams/7819701  1339
# 13             Virtus.pro  /teams/1883502  1329
# 14  Sparking Arrow Gaming  /teams/7407260  1316
# 15           BOOM Esports  /teams/7732977  1314
# 16               Geek Fam  /teams/3586078  1309
# 17            Quincy Crew  /teams/7390454  1307
# 18                     OG  /teams/2586976  1304
# ...
